# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ClimateWaffles_DataSet_Warangal.csv")

# %% [markdown]
# Nizamabad

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ClimateWaffles_DataSet_Nizamabad.csv")

# %% [markdown]
# Adilabad

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ClimateWaffles_DataSet _Adilabad.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=751f2e7a8b8f3400211fe69509d5d2b50b317cab00764bc5e5b9d8e4ba8841ce
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
# Successfully built sklearn
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
print(df.isnull().sum())
# Out:
# Month/ Sampling Location     0
# NOx                         48
# CO                          24
# PM2.5                       36
# PM10                        48
# Ozone                       48
# NH3                         36
# SO2                         36
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0]*100).sort_values(ascending=False)
# Out:
# NOx                         57.142857
# PM10                        57.142857
# Ozone                       57.142857
# PM2.5                       42.857143
# NH3                         42.857143
# SO2                         42.857143
# CO                          28.571429
# Month/ Sampling Location     0.000000
# dtype: float64

# %%
df.describe()
# Out:
#              NOx         CO        PM10      Ozone        NH3        SO2
# count  36.000000  60.000000   36.000000  36.000000  48.000000  48.000000
# mean   27.408056   0.674000   73.554167  38.036667  41.005625   8.110729
# std     8.552257   0.190443   13.237417   7.700572  19.671392   1.575264
# min    14.370000   0.500000   49.500000  31.370000  20.000000   5.820000
# 25%    21.500000   0.530000   65.375000  31.370000  22.000000   7.200000
# 50%    26.035000   0.600000   72.375000  34.080000  32.500000   7.900000
# 75%    33.955000   0.720000   82.337500  48.660000  59.827500   8.562500
# max    47.850000   1.020000  111.000000  48.660000  70.000000  15.370000

# %%
df.set_index('Month/ Sampling Location',inplace=True)

# %%
df.columns
# Out:
# Index(['NOx', 'CO', 'PM2.5', 'PM10', 'Ozone', 'NH3', 'SO2'], dtype='object')

# %%
df = df.dropna(how='all')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, Jan-16 to Dec-20
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOx     36 non-null     float64
#  1   CO      60 non-null     float64
#  2   PM2.5   48 non-null     object
#  3   PM10    36 non-null     float64
#  4   Ozone   36 non-null     float64
#  5   NH3     48 non-null     float64
#  6   SO2     48 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.8+ KB

# %%
df.head(100)
# Out:
#                             NOx    CO  PM2.5    PM10  Ozone    NH3     SO2
# Month/ Sampling Location
# Jan-16                    16.52  1.02  32.56   67.75  31.37  22.00   6.770
# Feb-16                    14.37  1.02  32.56   65.00  31.37  21.00   5.820
# Mar-16                    22.30  1.02  32.56   65.50  31.37  23.00   6.900
# Apr-16                    19.50  1.02  32.56   71.50  31.37  21.00   6.570
# May-16                    16.75  1.02   34.5   79.75  31.37  21.00   7.150
# Jun-16                    17.25  1.02   34.5   69.25  31.37  24.50   7.500
# Jul-16                    18.75  1.02   34.5   57.00  31.37  21.00   6.750
# Aug-16                    16.87  1.02   34.5   49.50  31.37  21.00   5.870
# Sep-16                    18.70  1.02  30.62   52.00  31.37  20.00   7.200
# Oct-16                    21.50  1.02  30.62   61.50  31.37  22.00   7.200
# Nov-16                    25.00  1.02  30.62   75.75  31.37  21.50   7.250
# ...

# %%
df= df.drop(df.index[36:])

# %%
df.head(100)
# Out:
#                             NOx    CO  PM2.5    PM10  Ozone    NH3     SO2  \
# Month/ Sampling Location
# Jan-16                    16.52  1.02  32.56   67.75  31.37  22.00   6.770
# Feb-16                    14.37  1.02  32.56   65.00  31.37  21.00   5.820
# Mar-16                    22.30  1.02  32.56   65.50  31.37  23.00   6.900
# Apr-16                    19.50  1.02  32.56   71.50  31.37  21.00   6.570
# May-16                    16.75  1.02   34.5   79.75  31.37  21.00   7.150
# Jun-16                    17.25  1.02   34.5   69.25  31.37  24.50   7.500
# Jul-16                    18.75  1.02   34.5   57.00  31.37  21.00   6.750
# Aug-16                    16.87  1.02   34.5   49.50  31.37  21.00   5.870
# Sep-16                    18.70  1.02  30.62   52.00  31.37  20.00   7.200
# Oct-16                    21.50  1.02  30.62   61.50  31.37  22.00   7.200
# Nov-16                    25.00  1.02  30.62   75.75  31.37  21.50   7.250
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Month/ Sampling Location'>

# %%
def get_PM10_subindex(x):
    if x <= 50:
        return x
    elif x > 50 and x <= 100:
        return x
    elif x > 100 and x <= 250:
        return 100 + (x - 100) * 100 / 150
    elif x > 250 and x <= 350:
        return 200 + (x - 250)
    elif x > 350 and x <= 430:
        return 300 + (x - 350) * 100 / 80
    elif x > 430:
        return 400 + (x - 430) * 100 / 80
    else:
        return 0

df["PM10_SubIndex"] = df["PM10"].astype(float).apply(lambda x: get_PM10_subindex(x))
    
# PM2.5 Sub-Index calculation
def get_PM25_subindex(x):
    if x <= 30:
        return x * 50 / 30
    elif x > 30 and x <= 60:
        return 50 + (x - 30) * 50 / 30
    elif x > 60 and x <= 90:
        return 100 + (x - 60) * 100 / 30
    elif x > 90 and x <= 120:
        return 200 + (x - 90) * 100 / 30
    elif x > 120 and x <= 250:
        return 300 + (x - 120) * 100 / 130
    elif x > 250:
        return 400 + (x - 250) * 100 / 130
    else:
        return 0

df["PM2.5_SubIndex"] = df["PM2.5"].astype(float).apply(lambda x: get_PM25_subindex(x))


# SO2 Sub-Index calculation
def get_SO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x > 40 and x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x > 80 and x <= 380:
        return 100 + (x - 80) * 100 / 300
    elif x > 380 and x <= 800:
        return 200 + (x - 380) * 100 / 420
    elif x > 800 and x <= 1600:
        return 300 + (x - 800) * 100 / 800
    elif x > 1600:
        return 400 + (x - 1600) * 100 / 800
    else:
        return 0

df["SO2_SubIndex"] = df["SO2"].astype(float).apply(lambda x: get_SO2_subindex(x))

# NOx Sub-Index calculation
def get_NOx_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x > 40 and x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x > 80 and x <= 180:
        return 100 + (x - 80) * 100 / 100
    elif x > 180 and x <= 280:
        return 200 + (x - 180) * 100 / 100
    elif x > 280 and x <= 400:
        return 300 + (x - 280) * 100 / 120
    elif x > 400:
        return 400 + (x - 400) * 100 / 120
    else:
        return 0

df["NOx_SubIndex"] = df["NOx"].astype(float).apply(lambda x: get_NOx_subindex(x))

# NH3 Sub-Index calculation
def get_NH3_subindex(x):
    if x <= 200:
        return x * 50 / 200
    elif x > 200 and x <= 400:
        return 50 + (x - 200) * 50 / 200
    elif x > 400 and x <= 800:
        return 100 + (x - 400) * 100 / 400
    elif x > 800 and x <= 1200:
        return 200 + (x - 800) * 100 / 400
    elif x > 1200 and x <= 1800:
        return 300 + (x - 1200) * 100 / 600
    elif x > 1800:
        return 400 + (x - 1800) * 100 / 600
    else:
        return 0

df["NH3_SubIndex"] = df["NH3"].astype(float).apply(lambda x: get_NH3_subindex(x))

# CO Sub-Index calculation
def get_CO_subindex(x):
    if x <= 1:
        return x * 50 / 1
    elif x > 1 and x <= 2:
        return 50 + (x - 1) * 50 / 1
    elif x > 2 and x <= 10:
        return 100 + (x - 2) * 100 / 8
    elif x > 10 and x <= 17:
        return 200 + (x - 10) * 100 / 7
    elif x > 17 and x <= 34:
        return 300 + (x - 17) * 100 / 17
    elif x > 34:
        return 400 + (x - 34) * 100 / 17
    else:
        return 0

df["CO_SubIndex"] = df["CO"].astype(float).apply(lambda x: get_CO_subindex(x))

# O3 Sub-Index calculation
def get_Ozone_subindex(x):
    if x <= 50:
        return x * 50 / 50
    elif x > 50 and x <= 100:
        return 50 + (x - 50) * 50 / 50
    elif x > 100 and x <= 168:
        return 100 + (x - 100) * 100 / 68
    elif x > 168 and x <= 208:
        return 200 + (x - 168) * 100 / 40
    elif x > 208 and x <= 748:
        return 300 + (x - 208) * 100 / 539
    elif x > 748:
        return 400 + (x - 400) * 100 / 539
    else:
        return 0

df["Ozone_SubIndex"] = df["Ozone"].astype(float).apply(lambda x: get_Ozone_subindex(x))

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True);
